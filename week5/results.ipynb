# %%
import numpy as np
from gradient_methods import experiments_gradient_descent, expirements_momentum, experiments_weight_decay
from line_search import run_line_search
from SGD import experiments_SGD
from Newton_method import run_newton_method

# Input data
#to access test data:
data = np.load('test_data.npz')
X_test_norm = data['X_test_norm']
Y_test_norm = data['Y_test_norm']
X_test_raw = data['X_test_raw']
Y_test_raw = data['Y_test_raw']

#to access train data:
data = np.load('train_data.npz')
X_train_norm = data['X_train_norm']
Y_train_norm = data['Y_train_norm']
X_train_raw = data['X_train_raw']
Y_train_raw = data['Y_train_raw']
split = int(0.8*len(X_train_norm))
X_train_norm_gd = X_train_norm[:split-1]
X_train_norm_val = X_train_norm[split:]
Y_train_norm_gd = Y_train_norm[:split-1]
Y_train_norm_val = Y_train_norm[split:]
# Targets

if __name__ == "__main__":
  weights = np.random.rand(X_train_norm_gd.shape[1])
  experiments_gradient_descent((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, max_iter=10000)
  expirements_momentum((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, 0.01, max_iter=10000)
  experiments_weight_decay((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, 0.1, max_iter=5500, alpha=0.9)
  run_line_search()
  experiments_SGD((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val),
                               (X_test_norm, Y_test_norm), weights, 100)
  run_newton_method((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, max_iter=10)
# Out:
# Stopped after 1988 iterations
# E_train: 0.029326976982780407, E_test: 0.04974121343714567
# Misclassified train set: 0.0
# CPU time: 20.39989185333252
# Stopped after 9999 iterations
# E_train: 0.2453384948772503, E_test: 0.2230707029991303
# Misclassified train set: 6.575073601570169
# CPU time: 98.10649514198303
# Stopped after 9999 iterations
# E_train: 0.07571606928243879, E_test: 0.09422067584075842
# Misclassified train set: 3.1894013738959726
# CPU time: 97.13059139251709
# Stopped after 9999 iterations
# E_train: 0.034616123782196424, E_test: 0.05079110244688675
# Misclassified train set: 1.521099116781155
# CPU time: 100.0204963684082
# Stopped after 4009 iterations
# E_train: 0.029251792558614976, E_test: 0.049703218494099005
# Misclassified train set: 0.0
# CPU time: 38.09241080284119
# Stopped after 9999 iterations
# E_train: 0.041480225213974126, E_test: 0.05608475543918481
# Misclassified train set: 1.8645731108930308
# CPU time: 103.14823484420776
# Stopped after 35 iterations
# E_train: 0.5254372464029369, E_test: 0.437921981963949
# Misclassified train set: 0.0
# CPU time: 0.5381510257720947
# Stopped after 22 iterations
# E_train: 0.5347938914610185, E_test: 0.44284585806733884
# Misclassified train set: 0.0
# CPU time: 0.3493509292602539
# Stopped after 9 iterations
# E_train: 0.5727690177858635, E_test: 0.5634583409506685
# Misclassified train set: 0.0
# CPU time: 0.22550654411315918
# Stopped after 8 iterations
# E_train: 0.8217573318972764, E_test: 0.8605758557279365
# Misclassified train set: 0.0
# CPU time: 0.22606277465820312
# Stopped after 7 iterations
# E_train: 0.728368016452029, E_test: 0.7536005316574877
# Misclassified train set: 0.0
# CPU time: 0.24561357498168945
# Stopped after 3 iterations
# E_train: 0.5258368527005155, E_test: 0.48976970042227946
# Misclassified train set: 0.0
# CPU time: 0.18756628036499023
# Stopped after 3 iterations
# E_train: 0.834652125049358, E_test: 0.8745774563931529
# Misclassified train set: 0.0
# CPU time: 0.1807079315185547
# Stopped after 3 iterations
# E_train: 1.5642014826674382, E_test: 1.6794254056047204
# Misclassified train set: 0.0
# CPU time: 0.17827343940734863
# Stopped after 8 iterations
# E_train: 0.8228448184901899, E_test: 0.8653706804723217
# Misclassified train set: 0.0
# CPU time: 0.23464512825012207
# Line Search Analytics:
# Stopped after 250 iterations.
# Final training error = 0.02611, Final testing error = 0.04737
# Training set classification error = 78.25%
# Testing set classification error = 157.02%
# Elapsed wall clock time was 39.219101428985596 seconds
# Conjugate Gradient Descent Analytics:
# Stopped after 101 iterations.
# Final training error = 0.00498, Final testing error = 0.20862
# Training set classification error = 10.49%
# Testing set classification error = 206.08%
# Elapsed wall clock time was 15.604912519454956 seconds
# Batch size: 60, learning_rate: 0.5. Elapsed time: 1.0282659530639648
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.31334, Final train E = 0.55716
# Training set classification error = 225.71%
# Testing set classification error = 141.20%
# Batch size: 60, learning_rate: 0.1. Elapsed time: 1.0139226913452148
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.26948, Final train E = 0.51270
# Training set classification error = 210.99%
# Testing set classification error = 131.11%
# Batch size: 60, learning_rate: 0.01. Elapsed time: 1.0146796703338623
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.26575, Final train E = 0.50885
# Training set classification error = 210.99%
# Testing set classification error = 128.09%
# Batch size: 100, learning_rate: 0.5. Elapsed time: 0.943657398223877
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.17307, Final train E = 0.44189
# Training set classification error = 191.36%
# Testing set classification error = 101.87%
# Batch size: 100, learning_rate: 0.1. Elapsed time: 0.9332997798919678
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.15787, Final train E = 0.42999
# Training set classification error = 181.55%
# Testing set classification error = 98.84%
# Batch size: 100, learning_rate: 0.01. Elapsed time: 0.9395520687103271
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.15650, Final train E = 0.42875
# Training set classification error = 181.55%
# Testing set classification error = 97.83%
# Batch size: 600, learning_rate: 0.5. Elapsed time: 0.7192990779876709
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14724, Final train E = 0.42064
# Training set classification error = 186.46%
# Testing set classification error = 98.84%
# Batch size: 600, learning_rate: 0.1. Elapsed time: 0.7268579006195068
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14552, Final train E = 0.41907
# Training set classification error = 186.46%
# Testing set classification error = 97.83%
# Batch size: 600, learning_rate: 0.01. Elapsed time: 0.7344753742218018
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14533, Final train E = 0.41891
# Training set classification error = 186.46%
# Testing set classification error = 97.83%
# Batch size: 1000, learning_rate: 0.5. Elapsed time: 0.7727415561676025
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14065, Final train E = 0.41434
# Training set classification error = 186.46%
# Testing set classification error = 93.80%
# Batch size: 1000, learning_rate: 0.1. Elapsed time: 0.7737622261047363
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.13969, Final train E = 0.41332
# Training set classification error = 186.46%
# Testing set classification error = 94.81%
# Batch size: 1000, learning_rate: 0.01. Elapsed time: 0.7794086933135986
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.13959, Final train E = 0.41322
# Training set classification error = 186.46%
# Testing set classification error = 94.81%
# Elapsed time: 1.0790855884552002
# Newton method:
# Stopped after 10 iterations.
# Final train E = 1.00887, Final train E = 1.22024
# Training set classification error = 353.29%
# Testing set classification error = 291.48%
