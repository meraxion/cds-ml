# %%
import numpy as np
from gradient_methods import experiments_gradient_descent, expirements_momentum, experiments_weight_decay
from line_search import run_line_search
from SGD import experiments_SGD
from Newton_method import run_newton_method

# Input data
#to access test data:
data = np.load('test_data.npz')
X_test_norm = data['X_test_norm']
Y_test_norm = data['Y_test_norm']
X_test_raw = data['X_test_raw']
Y_test_raw = data['Y_test_raw']

#to access train data:
data = np.load('train_data.npz')
X_train_norm = data['X_train_norm']
Y_train_norm = data['Y_train_norm']
X_train_raw = data['X_train_raw']
Y_train_raw = data['Y_train_raw']
split = int(0.8*len(X_train_norm))
X_train_norm_gd = X_train_norm[:split-1]
X_train_norm_val = X_train_norm[split:]
Y_train_norm_gd = Y_train_norm[:split-1]
Y_train_norm_val = Y_train_norm[split:]
# Targets

if __name__ == "__main__":
  weights = np.random.rand(X_train_norm_gd.shape[1])
  experiments_gradient_descent((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, max_iter=10000)
  expirements_momentum((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, 0.01, max_iter=10000)
  experiments_weight_decay((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, 0.1, max_iter=5500, alpha=0.9)
  run_line_search()
  experiments_SGD((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val),
                               (X_test_norm, Y_test_norm), weights, 100)
  run_newton_method((X_train_norm_gd, Y_train_norm_gd), (X_train_norm_val, Y_train_norm_val), (X_test_norm, Y_test_norm), weights, max_iter=10)
# Out:
# Gradient Descent Analytics:
# Stopped after 2572 iterations
# E_train: 0.02756, E_test: 0.05078
# Misclassified test set: 1.47%
# CPU time: 36.2407
# Gradient Descent Analytics:
# Stopped after 9999 iterations
# E_train: 0.25585, E_test: 0.24299
# Misclassified test set: 7.56%
# CPU time: 138.2167
# Gradient Descent Analytics:
# Stopped after 9999 iterations
# E_train: 0.07518, E_test: 0.09203
# Misclassified test set: 2.89%
# CPU time: 106.4853
# Gradient Descent Analytics:
# Stopped after 9999 iterations
# E_train: 0.03509, E_test: 0.05202
# Misclassified test set: 1.57%
# CPU time: 97.9856
# Gradient Descent Analytics:
# Stopped after 5159 iterations
# E_train: 0.02753, E_test: 0.05076
# Misclassified test set: 1.47%
# CPU time: 60.5911
# Gradient Descent with Momentum Analytics:
# Stopped after 9999 iterations
# E_train: 0.04240, E_test: 0.05794
# Misclassified test set: 1.82%
# CPU time: 122.4183
# Gradient Descent with Momentum Analytics:
# Stopped after 35 iterations
# E_train: 0.60637, E_test: 0.53291
# Misclassified test set: 13.84%
# CPU time: 0.7043
# Gradient Descent with Momentum Analytics:
# Stopped after 22 iterations
# E_train: 0.61349, E_test: 0.54041
# Misclassified test set: 13.98%
# CPU time: 0.4522
# Gradient Descent with Momentum Analytics:
# Stopped after 9 iterations
# E_train: 0.65913, E_test: 0.66048
# Misclassified test set: 16.98%
# CPU time: 0.3299
# Gradient Descent with Momentum Analytics:
# Stopped after 7 iterations
# E_train: 1.03262, E_test: 0.84113
# Misclassified test set: 16.68%
# CPU time: 0.2479
# Gradient Descent with Momentum Analytics:
# Stopped after 7 iterations
# E_train: 0.82246, E_test: 0.85904
# Misclassified test set: 20.22%
# CPU time: 0.2442
# Gradient Descent with Momentum Analytics:
# Stopped after 3 iterations
# E_train: 0.62561, E_test: 0.60617
# Misclassified test set: 15.46%
# CPU time: 0.2048
# Gradient Descent with Momentum Analytics:
# Stopped after 3 iterations
# E_train: 0.93555, E_test: 0.98734
# Misclassified test set: 22.08%
# CPU time: 0.2042
# Gradient Descent with Momentum Analytics:
# Stopped after 3 iterations
# E_train: 1.61064, E_test: 1.73429
# Misclassified test set: 31.11%
# CPU time: 0.1990
# Gradient Descent with Weight Decay Analytics:
# Stopped after 7 iterations
# E_train: 1.03340, E_test: 0.84558
# Misclassified train set: 16.68%
# CPU time: 0.2488
# Line Search Analytics:
# Stopped after 250 iterations.
# Final training error = 0.02494, Final testing error = 0.05001
# Training set classification error = 0.81%
# Testing set classification error = 1.57%
# Elapsed wall clock time was 55.9746 seconds
# Conjugate Gradient Descent Analytics:
# Stopped after 101 iterations.
# Final training error = 0.00407, Final testing error = 0.18516
# Training set classification error = 0.10%
# Testing set classification error = 2.21%
# Elapsed wall clock time was 24.1090 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.31540, Final train E = 0.56517
# Training set classification error = 2.21%
# Testing set classification error = 1.42%
# Batch size: 60, learning_rate: 0.5. Elapsed time: 1.1035 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.26989, Final train E = 0.51904
# Training set classification error = 2.11%
# Testing set classification error = 1.29%
# Batch size: 60, learning_rate: 0.1. Elapsed time: 1.0978 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.26610, Final train E = 0.51475
# Training set classification error = 2.11%
# Testing set classification error = 1.28%
# Batch size: 60, learning_rate: 0.01. Elapsed time: 1.1848 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.17300, Final train E = 0.43897
# Training set classification error = 1.82%
# Testing set classification error = 1.02%
# Batch size: 100, learning_rate: 0.5. Elapsed time: 0.9870 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.15845, Final train E = 0.42817
# Training set classification error = 1.82%
# Testing set classification error = 0.98%
# Batch size: 100, learning_rate: 0.1. Elapsed time: 1.0318 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.15711, Final train E = 0.42702
# Training set classification error = 1.82%
# Testing set classification error = 0.99%
# Batch size: 100, learning_rate: 0.01. Elapsed time: 1.0351 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14784, Final train E = 0.41951
# Training set classification error = 1.86%
# Testing set classification error = 0.95%
# Batch size: 600, learning_rate: 0.5. Elapsed time: 0.7868 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14609, Final train E = 0.41813
# Training set classification error = 1.86%
# Testing set classification error = 0.97%
# Batch size: 600, learning_rate: 0.1. Elapsed time: 0.8004 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14590, Final train E = 0.41799
# Training set classification error = 1.86%
# Testing set classification error = 0.97%
# Batch size: 600, learning_rate: 0.01. Elapsed time: 0.8311 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.14096, Final train E = 0.41406
# Training set classification error = 1.86%
# Testing set classification error = 0.94%
# Batch size: 1000, learning_rate: 0.5. Elapsed time: 0.8158 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.13997, Final train E = 0.41319
# Training set classification error = 1.86%
# Testing set classification error = 0.94%
# Batch size: 1000, learning_rate: 0.1. Elapsed time: 0.7941 seconds
# Stochastic Gradient Descent:
# Stopped after 100 iterations.
# Final train E = 0.13987, Final train E = 0.41309
# Training set classification error = 1.86%
# Testing set classification error = 0.94%
# Batch size: 1000, learning_rate: 0.01. Elapsed time: 0.8071 seconds
# Newton Method Analytics:
# Stopped after 10 iterations.
# Final train E = 1.00526, Final train E = 1.22022
# Training set classification error = 3.53%
# Testing set classification error = 2.90%
# Elapsed time: 1.0205 seconds

# %% [markdown]
# ## Discussion
#
# ### Gradient Descent
# Really only worth commenting on the case where learning rate = 0.001.
# Here, the algorithm does not seem to move large enough steps in the gradient direction, and therefore does not learn quickly enough. It both takes a while (1000+ iterations) to start seeing improvement, and after it flattens out the improvement is - obviously - not as quick as the others to reach near-optimal, and that's why it ends at 7.56% misclassification rate.
#
# It's also worth noting that Gradient Descent was the algorithm that generally took the longest, out of the gradient methods we tried, whether that was with momentum/weight decay or without, and that for larger step sizes, it took shorter time.
#
# #### With Momentum
# Momentum seems also generally to take its time, although we see an abrupt - nearly qualitative change between momentum learning rate 0.001 when alpha $= 0.8$ compared to $0.9$. I can't really explain what's happening there, other than that we started overfitting earlier than in the $0.8$ case.
#
# However, that seems also to generally be the case with momentum: it aborts early (due to us including early stopping with our momentum, which might have been a mistake, but this kind of experimentation is how you learn, isn't it?).
#
# #### With Weight Decay
# Weight decay received similar results as momentum and general GD.
#
# ### Line Search
# For line search, we ran it for 250 iterations and received results competitive with those in the problem specification. In clock time however, our Python implementation is shorter.
#
#
# ### Conjugate Gradient Descent
# It looks like our conjugate gradient descent actually started overfitting heavily on the training data, leading to it getting worse classification error on the testing set than even line search - though still good.
#
#
# ### Stochastic Gradient Descent
#
# ### Newton's Method
#
# ### General:
# Prompt:
# > Discuss how these results for this problem (logistic regression on the MNIST data) are expected to change for other data sets (more samples N, or more variablse n) and methods (more variables W, such as deep neural networks).
